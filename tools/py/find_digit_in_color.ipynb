# %%
import os
from PIL import Image

z1_x1 = 956
z1_x2 = 974
z2_x1 = 974
z2_x2 = 992

z3_x1 = 956
z3_x2 = 974
z4_x1 = 974
z4_x2 = 992
z5_x1 = 956
z5_x2 = 974
z6_x1 = 974
z6_x2 = 992
z7_x1 = 974
z7_x2 = 992
z8_x1 = 974
z8_x2 = 992

z1_y1 = 185
z1_y2 = 220
z2_y1 = 185
z2_y2 = 220
a_x1 = 100
a_x2 = 880
b_x1 = 956
b_x2 = 968
c_x1 = 968
c_x2 = 980
d_x1 = 986
d_x2 = 998
y0 = 266
height = 56

color_d = (255, 198, 61)
color_0 = (255, 244, 196)
color_b = (255, 228, 135)

folder_path = "D:\\z\\"
save_path = "D:\\zz\\"
fileNames = sorted(
    [os.path.splitext(f)[0] for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))],
    key=lambda x: int(x)  
)

for fileName in fileNames:
    ss = Image.open(folder_path + fileName + ".png")
    
    area = (z1_x1, z1_y1, z1_x2, z2_y2)
    cropped = ss.crop(area)
    cropped = cropped.convert("L").point(lambda x: 255 if x > 128 else 0, mode="1") 
    display(cropped)  
    cropped.save(folder_path + fileName + "_1" + ".png")
    
    area = (z2_x1, z1_y1, z2_x2, z2_y2)
    cropped = ss.crop(area)
    cropped = cropped.convert("L").point(lambda x: 255 if x > 128 else 0, mode="1") 
    display(cropped)
    cropped.save(folder_path + fileName + "_2" + ".png")

rgb = ss.convert("RGB")
pixels = rgb.load()
# Out:
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# <PIL.Image.Image image mode=1 size=18x35>
# ...
